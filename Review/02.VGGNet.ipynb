# %% [markdown]
# # __1.Background_knowledge__
#
# - (1): receptive_field(수용 영역), feature map이 이미지의 어떤 영역을 보고 계산되었는지
# - (2):

# %% [markdown]
# # __2.Problem__
#
# - AlexNet의 CNN이후, depth를 깊게하기 위한 연구가 시작되었다. AlexNet의 kernel(filter)은, 11x11, 5x5, 3x3 으로, 큰 kernel에 의해 Parameter수가 많았다. 이는 깊은 네트워크를 만드는데 어려움이 있었다.

# %% [markdown]
# # __3.Contribution__
#
# - 3x3 filter 반복 사용
# - LRN 제거
# - AlexNet의 GPU 병렬 사용 -> 단일구조 변경

# %% [markdown]
# # 4. 3x3 kernel usage
#
# - 위 논문의 가장 핵심적인 부분으로, kernel의 크기가 커진다면 Parameter 수가 증가하고,

# %% [markdown]
# # Question
#
# - (1): 3x3으로 filter 설정시, feature_map이 더 많아지면서 결국 연산량이 증가하는것 아닌가? 어떻게 더 깊은 layer를 쌓았을지.
#     -
# - (2)
